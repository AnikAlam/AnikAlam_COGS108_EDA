# %% [markdown]
# # COGS 108 - Group065- Exploring the Impacts of Taylor Swift's Eras Tour on Local Hospitality Services and Inflation
#
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [ X ] YES - make available
# * [  ] NO - keep private
#
# # Names
#
# - Anik Alam
# - Chloe Kwan
# - Sophie Phung
# - Anusha Rao
# - Patric Sanchez
#
# # Abstract
#
# Our project examines the economic impact of Taylor Swift's Eras Tour on local economies in North America between March 2023 and August 2023, to understand how factors such as venue size, average ticket price, and concert attendance influenced inflation in sectors including retail, hospitality, and the restaurant industry. By analyzing a dataset that includes variables such as hospitality prices and Consumer Price Index (CPI) inflation rates for each of the concerts, we aim to identify the economic impact linked to the tour.
#
# Our motivation for this project comes from the well-known cultural impact of Taylor Swift, including reports of economic boosts in cities hosting Eras Tour stops. Known as "Swiftonomics," there has been increased tourism, greater demand for local services, and inflation in many sectors. There have been speculation and news articles highlighting the tour's economic contributions, but we wanted to create a detailed, city-by-city analysis exploring the tour and its specific impact.
#
# Our findings show that cities on the Eras Tour route experienced significant increases in local economic activity. The data reveal a correlation between higher concert attendance and greater inflation rates, suggesting that the presence of Swift's fans played a critical role in increasing demand and prices. The results also bring to light that while major events such as the Eras tour can stimulate economic growth and job creation in cities, they may also cause issues related to inflation and affordability for local residents. Our research project contributes to a larger understanding of how economic dynamics can change due to major entertainment events and provides a framework for future research of similar events.

# %% [markdown]
# # FINAL PROJECT PRESENTATION VIDEO
# - [Link to video](https://drive.google.com/file/d/1mPr_DmAk2uVVxOilTpQLIT7idu31M9vv/view)

# %% [markdown]
# # Research Question

# %% [markdown]
# Our research question is: What is the economic impact of Taylor Swift’s Eras Tour stops in North America between March 2023 to August 2023 on the local economics of different cities? How do factors (such as venue size, average ticket price, concert attendance, etc.) impact inflation in sectors such as retail, hospitality, and the restaurant industry?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# In 2023, singer Taylor Swift embarked on a tour of her greatest hit songs, aptly titled “The Eras Tour”. The tour spanned 53 stops throughout the United States, beginning in March and ending in August. Swift then continued touring in Latin America, Asia, and Australia into 2024, with plans to continue touring Europe and the remaining North American stops till the end of 2024.
#
# Swift has been praised for helping boost the tourism industry at the various cities she visited on her United States tour. As fans flocked to city centers to witness her performance, they expended savings accumulated during the COVID-19 pandemic on tourism and hospitality prior to the big event. In what is dubbed as “Swiftonomics<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1),” the economic implications of the Eras Tour fascinated economists as they gathered data to understand these statistics. States reported receiving millions towards their economies, with metropolitans, such as Los Angeles, also seeing an increase in thousands of jobs to meet the demand. However, with the increased willingness to spend on tourism, there was also record inflation in certain sectors, as the prices of transportation and lodging shot up, with dwindling supply attempting to match significant demand.
#
# Previous studies that have been done on this topic primarily consist of new articles which report increases in spending when Swift visits these cities. For example, this study<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) states that the Eras Tour added 5 billion dollars to the economy. Other research works<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) examine the use of the words “Taylor Swift” as a marketing tool, whether or not the singer even stops in the city. For example, in San Diego, a sushi restaurant hosted a Swift-themed night the same week the singer was in Los Angeles, and immediately sold out. According to another study<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4), of the 53 stops in 20 cities, the average fan spent nearly $1300 on travel, hotel stays, food, and merchandise. In Pittsburgh, average room rates saw a 106% increase, with 83% of guests coming from outside the host county. We have not seen a comprehensive city-by-city analysis, and are curious as to which cities saw the greatest boosts in revenue, which sectors are most crucial to economic success, and if ticket pricing and number sold come into contention. With such a variety in demographics and areas visited, our group is interested in analyzing which areas saw the greatest growth in revenue, and where inflation hurt consumers the most.
# 1. <a name="https://www.investopedia.com/swiftonomics-definition-8601178"></a> [^](#cite_ref-1) Mitra, M. (8 Mar 2024) Swiftonomics: The Economic Influence of Taylor Swift. *Investopedia*. https://www.investopedia.com/swiftonomics-definition-8601178
# 2. <a name="https://www.cbsnews.com/news/taylor-swift-eras-tour-boosted-economy-tourism-federal-reserve-how-much-money-made/"></a> [^](#cite_ref-2) O'Kane, C. (18 Jul 2023) The Federal Reserve says Taylor Swift's Eras Tour boosted the economy. One market research firm estimates she could add $5 billion *CBS New*. https://www.cbsnews.com/news/taylor-swift-eras-tour-boosted-economy-tourism-federal-reserve-how-much-money-made/
# 3. <a name="https://www.cnbc.com/2024/03/01/the-taylor-swift-economic-effect-has-reached-every-town-in-america.html"></a> [^](#cite_ref-3) Williams, K. (1 Mar 2024) The Taylor Swift economy has reached every town in America, from small business moms to skating rinks and sushi bars. *CNBC*. https://www.cnbc.com/2024/03/01/the-taylor-swift-economic-effect-has-reached-every-town-in-america.html
# 4. <a name="https://www.ustravel.org/news/taylor-swift-impact-5-months-and-5-billion"></a> [^](#cite_ref-4) (19 Sept 2023) The Taylor Swift Impact – 5 Months and $5+ Billion. *U.S. Travel Association*. https://www.ustravel.org/news/taylor-swift-impact-5-months-and-5-billion

# %% [markdown]
# # Hypothesis

# %% [markdown]
# - We hypothesize that North American stops on Taylor Swift’s “The Eras Tour” will cause local economies to see a sharp spike in prices due to inflation, particularly within hotels, transportation, food, and other hospitality-based sectors.
# - Due to Taylor Swift’s popularity, cultural impact, and massive fanbase, we expect that businesses in the hospitality sector in cities on the tour route will increase their pricing for services/accommodations accordingly in order to maximize profits, given that a large influx of tourists will naturally increase the demand and congestion of services.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name: Eras Tour Dataset
#   - Link to the dataset: [https://docs.google.com/spreadsheets/d/1ZScdvaeIbX-Q8OfbtvAlR-XHEtl-dgJ3EHmB5yltKUg/edit#gid=0](https://docs.google.com/spreadsheets/d/1ZScdvaeIbX-Q8OfbtvAlR-XHEtl-dgJ3EHmB5yltKUg/edit#gid=0)
#   - Number of observations: 53
#   - Number of variables: 14
# - Dataset #2
#   - Dataset Name: Reputation Tour Dataset
#   - Link to the dataset: [https://docs.google.com/spreadsheets/d/1ZScdvaeIbX-Q8OfbtvAlR-XHEtl-dgJ3EHmB5yltKUg/edit#gid=408156481](https://docs.google.com/spreadsheets/d/1ZScdvaeIbX-Q8OfbtvAlR-XHEtl-dgJ3EHmB5yltKUg/edit#gid=408156481)
#   - Number of observations: 38
#   - Number of variables: 12
#
# ### Description of Datasets:
# Due to the nature of our focus for this project, we chose these datasets to see if we can locate and define any changes in local economy and business prices around the dates of the Taylor Swift concert. In order to complete our analysis, we combined data from various sources to create a new dataset for our specific question. These were compiled using a variety of sources such as the Federal Bureau of Labor statistics for economic variables, hotel hospitality from local newspapers of each respective town, stadium sizes along with tour dates and ticket prices from wikipedia, and more.
# The metrics include the number of attendees and revenue in dollars, which can serve as proxies for the economic impact of the concerts. Data types include dates, categorical variables, and numerical variables. Additionally, specific components such as food price increases and leisure and hospitality gains in order to determine the inflation noted by the influence of the tour. We also used Consumer Price Index (CPI) to gauge the inflation at the time by comparing the current and previous year’s market basket price for an overall inflation rate. Thus, comparing the hospitality prices before and after the Taylor Swift Eras Tour using the Reputation Tour forms the data set for our analysis.
# Rows with null entries were kept with the null entry ignored, as each row in its entirety was important and could not be dropped.

# %% [markdown]
# ## Eras Tour Dataset
#
# #### Description
# - This dataset lists data pertaining to all of the concerts Taylor Swift held throughout the Eras Tour, from March 17, 2023 to August 9, 2023.
#
# #### Variables
# - **Stop Number:** The stop number a concert was in relation to the tour.
# - **Date:** The date that a concert was held.
# - **Day of the Week:** The day of the week that the concert was held.
# - **City:** The city where the concert took place.
# - **State:** The state where the concert took place.
# - **Venue Name:** The name of the venue where the concert took place.
# - **Average Ticket Price:** The average price of a ticket for a concert, in dollars.
# - **Concert Attendance:** The total number of people in attendance for this concert.
# - **Avg. Hospitality Price Pre-Swift:** The average cost of hospitality, before a Taylor Swift concert.
# - **Avg. Hospitality Price Post-Swift:** The average cost of hospitality, after a Taylor Swift concert.
# - **Average Leisure & Hospitality Gains (in thousands):** The average gains earned by businesses in the leisure and hospitality sector.
# - **Average Inflation noted in CPI(%):** The average inflation rate as measured by the Consumer Price Index, presented as a percentage.
# - **Food Away From Home Percent Increase(%):** Percentage increase in the cost of food consued away from home, such as dining out expenses over time.

# %%
#Imports to set up our packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read  dataframe and include proper columns
eras_df = pd.read_csv('eras_tour_dataset.csv')

# View how the dataset looks like
eras_df.head()
# Out:
#    Stop Number            Date Day of Week       City    State  \
# 0            1  March 17, 2023      Friday   Glendale  Arizona
# 1            2  March 18, 2023    Saturday   Glendale  Arizona
# 2            3  March 24, 2023      Friday   Paradise   Nevada
# 3            4  March 25, 2023    Saturday   Paradise   Nevada
# 4            5  March 31, 2023      Friday  Arlington    Texas
#
#            Venue Name Venue Size  Average Ticket Price Concert Attendance  \
# 0  State Farm Stadium     78,600                   250             69,000
# 1  State Farm Stadium     78,600                   250              77000
# 2   Allegiant Stadium     71,835                   200              40000
# 3   Allegiant Stadium     71,835                   200              40000
# 4        AT&T Stadium    100,000                   300              70202
#
#    Avg. Hospitality Price Pre-Swift  Avg. Hospitality Price Post-Swift  \
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# Rename columns for conciseness

eras_df.rename(columns={
    'Stop Number': 'Stop No.',
    'Date': 'Date',
    'Day of Week': 'Day',
    'City': 'City',
    'State': 'State',
    'Venue Name': 'Venue',
    'Venue Size': 'Capacity',
    'Average Ticket Price': 'Avg. Ticket Price',
    'Concert Attendance': 'Attendance',
    'Avg. Hospitality Price Pre-Swift': 'Pre-Swift Hosp. Price',
    'Avg. Hospitality Price Post-Swift': 'Post-Swift Hosp. Price',
    'Average Leisure & Hospitality Gains (in thousands)': 'Avg. Hosp. Gains (000s)',
    'Average Inflation noted in CPI(%)': 'Avg. Inflation CPI (%)',
    'Food Away From Home Percent Increase(%)': 'Food Away Home Inc. (%)'
}, inplace=True)
eras_df.head()
# Out:
#    Stop No.            Date       Day       City    State               Venue  \
# 0         1  March 17, 2023    Friday   Glendale  Arizona  State Farm Stadium
# 1         2  March 18, 2023  Saturday   Glendale  Arizona  State Farm Stadium
# 2         3  March 24, 2023    Friday   Paradise   Nevada   Allegiant Stadium
# 3         4  March 25, 2023  Saturday   Paradise   Nevada   Allegiant Stadium
# 4         5  March 31, 2023    Friday  Arlington    Texas        AT&T Stadium
#
#   Capacity  Avg. Ticket Price Attendance  Pre-Swift Hosp. Price  \
# 0   78,600                250     69,000                    142
# 1   78,600                250      77000                    142
# 2   71,835                200      40000                     83
# 3   71,835                200      40000                     83
# 4  100,000                300      70202                    126
#
#    Post-Swift Hosp. Price  Avg. Hosp. Gains (000s)  Avg. Inflation CPI (%)  \
# ...

# %%
# Check for any rows with null values

rows_with_null = eras_df.isnull().any(axis=1).sum()
print('Number of rows with at least one null value: ' + str(rows_with_null))
# Out:
# Number of rows with at least one null value: 7

# %%
# Since we know that there exists null values in this dataset, we are interested in figuring out what columns they belong to. 

null_columns = eras_df.isnull().sum()
null_columns = null_columns[null_columns > 0]
null_columns
# Out:
# Avg. Inflation CPI (%)     7
# Food Away Home Inc. (%)    4
# dtype: int64

# %% [markdown]
# #### For the purposes of this project and scale of our dataset, we do not have the leisure of simply dropping all rows that have a null entry. As such, the specific entries will simply be ignored, as the row in its entirety is important.

# %%
# Check the datatypes of the dataframe to see if normalization of columns are required

eras_df.dtypes
# Out:
# Stop No.                     int64
# Date                        object
# Day                         object
# City                        object
# State                       object
# Venue                       object
# Capacity                    object
# Avg. Ticket Price            int64
# Attendance                  object
# Pre-Swift Hosp. Price        int64
# Post-Swift Hosp. Price       int64
# Avg. Hosp. Gains (000s)    float64
# Avg. Inflation CPI (%)     float64
# Food Away Home Inc. (%)    float64
# dtype: object

# %%
# Change capacity column to numerical representation

def capacity_standardize(str_in):
    str_in = str_in.replace(",", "")
    return int(str_in)

eras_df['Capacity'] = eras_df['Capacity'].apply(capacity_standardize)

# %%
# Change attendance column to numerical representation

def attendance_standardize(str_in):
    if ',' in str_in:
        str_in = str_in.replace(',', '')
    return int(str_in)

eras_df['Attendance'] = eras_df['Attendance'].apply(attendance_standardize)

# %%
# Convert date column to DateTime

eras_df['Date'] = pd.to_datetime(eras_df['Date'])

# %%
# Re-check data types to ensure correct standardization 

eras_df.dtypes
# Out:
# Stop No.                            int64
# Date                       datetime64[ns]
# Day                                object
# City                               object
# State                              object
# Venue                              object
# Capacity                            int64
# Avg. Ticket Price                   int64
# Attendance                          int64
# Pre-Swift Hosp. Price               int64
# Post-Swift Hosp. Price              int64
# Avg. Hosp. Gains (000s)           float64
# Avg. Inflation CPI (%)            float64
# Food Away Home Inc. (%)           float64
# dtype: object

# %%
# Final look of Taylor Swift's Eras Tour dataset that we will be working with

eras_df.head()
# Out:
#    Stop No.       Date       Day       City    State               Venue  \
# 0         1 2023-03-17    Friday   Glendale  Arizona  State Farm Stadium
# 1         2 2023-03-18  Saturday   Glendale  Arizona  State Farm Stadium
# 2         3 2023-03-24    Friday   Paradise   Nevada   Allegiant Stadium
# 3         4 2023-03-25  Saturday   Paradise   Nevada   Allegiant Stadium
# 4         5 2023-03-31    Friday  Arlington    Texas        AT&T Stadium
#
#    Capacity  Avg. Ticket Price  Attendance  Pre-Swift Hosp. Price  \
# 0     78600                250       69000                    142
# 1     78600                250       77000                    142
# 2     71835                200       40000                     83
# 3     71835                200       40000                     83
# 4    100000                300       70202                    126
#
#    Post-Swift Hosp. Price  Avg. Hosp. Gains (000s)  Avg. Inflation CPI (%)  \
# ...

# %% [markdown]
# ## Dataset #2 (if you have more than one, use name instead of number here)

# %% [markdown]
# ## Reputation Tour Dataset
#
# ### Description:
# - This dataset lists data pertaining to many of the concerts Taylor Swift held throughout the Reputation Tour, from May 8, 2018 to October 6, 2018.

# %%
# Initial read and load dataframe 

reputation_df = pd.read_csv('reputation_tour_dataset.csv')
reputation_df.head()
# Out:
#    Stop Number Date (2018) Day of Week         City       State  \
# 0            1       May 8     Tuesday     Glendale     Arizona
# 1            2      May 11      Friday  Santa Clara  California
# 2            3      May 12    Saturday  Santa Clara  California
# 3            4      May 18      Friday     Pasadena  California
# 4            5      May 19    Saturday     Pasadena  California
#
#                       Venue Name Venue Size  Average Ticket Price  \
# 0  University of Phoenix Stadium      63400                   122
# 1                 Levi's Stadium     68,500                   130
# 2                 Levi's Stadium     68,500                   130
# 3                      Rose Bowl     96,400                   138
# 4                      Rose Bowl     96,400                   138
#
#    Concert Attendance  Avg. Hospitality Price Pre-Swift  \
# 0               59157                               NaN
# 1               53775                               NaN
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# Rename columns

reputation_df.rename(columns={
    'Stop Number': 'Stop No.',
    'Date (2018)': 'Date',
    'Day of Week': 'Day',
    'City': 'City',
    'State': 'State',
    'Venue Name': 'Venue',
    'Venue Size': 'Capacity',
    'Average Ticket Price': 'Avg. Ticket Price',
    'Concert Attendance': 'Attendance',
    'Avg. Hospitality Price Pre-Swift': 'Pre-Swift Hosp. Price',
    'Avg. Hospitality Price Post-Swift': 'Post-Swift Hosp. Price',
    'Average Leisure & Hospitality Gains (in thousands)': 'Avg. Hosp. Gains (000s)',
    'Average Inflation noted in CPI(%)': 'Avg. Inflation CPI (%)',
    'Food Away From Home Percent Increase(%)': 'Food Away Home Inc. (%)'
}, inplace=True)
reputation_df.head()
# Out:
#    Stop No.    Date       Day         City       State  \
# 0         1   May 8   Tuesday     Glendale     Arizona
# 1         2  May 11    Friday  Santa Clara  California
# 2         3  May 12  Saturday  Santa Clara  California
# 3         4  May 18    Friday     Pasadena  California
# 4         5  May 19  Saturday     Pasadena  California
#
#                            Venue Capacity  Avg. Ticket Price  Attendance  \
# 0  University of Phoenix Stadium    63400                122       59157
# 1                 Levi's Stadium   68,500                130       53775
# 2                 Levi's Stadium   68,500                130       53775
# 3                      Rose Bowl   96,400                138       59042
# 4                      Rose Bowl   96,400                138       59042
#
#    Pre-Swift Hosp. Price  Post-Swift Hosp. Price  Avg. Hosp. Gains (000s)  \
# 0                    NaN                     NaN                      4.7
# ...

# %%
# Remove null columns

reputation_df.drop(columns=['Pre-Swift Hosp. Price', 'Post-Swift Hosp. Price'], inplace=True)

# %%
# Check for any rows with null values

rows_with_null2 = reputation_df.isnull().any(axis=1).sum()
print('Number of rows with at least one null value: ' + str(rows_with_null2))
# Out:
# Number of rows with at least one null value: 0

# %%
# Change capacity column to numerical representation

reputation_df['Capacity'] = reputation_df['Capacity'].apply(capacity_standardize)

# %%
# Change date column to DateTime

reputation_df['Date'] = reputation_df['Date'] + ', 2018'

reputation_df['Date'] = pd.to_datetime(reputation_df['Date'], format='%B %d, %Y')

# %%
# Check datatypes

reputation_df.dtypes
# Out:
# Stop No.                            int64
# Date                       datetime64[ns]
# Day                                object
# City                               object
# State                              object
# Venue                              object
# Capacity                            int64
# Avg. Ticket Price                   int64
# Attendance                          int64
# Avg. Hosp. Gains (000s)           float64
# Avg. Inflation CPI (%)            float64
# Food Away Home Inc. (%)           float64
# dtype: object

# %%
# Final look of Taylor Swift's Reputation Tour dataset that we will be working with

reputation_df.head()
# Out:
#    Stop No.       Date       Day         City       State  \
# 0         1 2018-05-08   Tuesday     Glendale     Arizona
# 1         2 2018-05-11    Friday  Santa Clara  California
# 2         3 2018-05-12  Saturday  Santa Clara  California
# 3         4 2018-05-18    Friday     Pasadena  California
# 4         5 2018-05-19  Saturday     Pasadena  California
#
#                            Venue  Capacity  Avg. Ticket Price  Attendance  \
# 0  University of Phoenix Stadium     63400                122       59157
# 1                 Levi's Stadium     68500                130       53775
# 2                 Levi's Stadium     68500                130       53775
# 3                      Rose Bowl     96400                138       59042
# 4                      Rose Bowl     96400                138       59042
#
#    Avg. Hosp. Gains (000s)  Avg. Inflation CPI (%)  Food Away Home Inc. (%)
# 0                      4.7                1.193210                 1.005520
# ...

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis
#
# Carry out whatever EDA you need to for your project.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.

# %% [markdown]
# ### Visualizing Venue Dynamics: Capacity, Attendance, and City Variances
#
# We first aim to generate visualizations to analyze venue capacity, attendance, and their variations across different cities. They offer insights into possible venue dynamics and attendance patterns at play.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

#scatterplot comparing the maximum capacity of a given venue to the number of tickets sold, with a line of best fit to the third order
plt.figure(figsize=(8, 6))
sns.scatterplot(data=eras_df, x='Capacity', y='Attendance')
sns.regplot(data=eras_df, x='Capacity', y='Attendance', scatter=False, color='red', order=3)  # Fit a curve
plt.title('Attendance Per Capacity of Venue')
plt.xlabel('Capacity')
plt.xticks(rotation=45)
plt.ylabel('Tickets Sold')
plt.grid(True)
plt.show()
print("This graph displays the tickets sold relative to the capacity of each venue(data point) and shows how almost every data point will have sold tickets equal or close to capacity")

mean_capacity = eras_df.groupby('City')['Capacity'].mean().reset_index()
mean_attendance = eras_df.groupby('City')['Attendance'].mean().reset_index()

plt.figure(figsize=(10, 4))
sns.barplot(data= eras_df, x="City", y="Capacity")
sns.lineplot(data=mean_capacity, x='City', y='Capacity', marker='o', color='red')
plt.title("Venue Capacity by City")
plt.xlabel("City")
plt.xticks(rotation=45)
plt.ylabel("Capacity")
plt.show()

plt.figure(figsize=(10, 4))
sns.barplot(data= eras_df, x="City", y="Attendance")
sns.lineplot(data=mean_attendance, x='City', y='Attendance', marker='o', color='red')
plt.title("Venue Attendance by City")
plt.xlabel("City")
plt.xticks(rotation=45)
plt.ylabel("Attendance")
plt.show()

print("The two graphs above represent the capacity and attendance per city, respectively; to allow for comparison of whether or not attendance was at, or close to capacity.")
# Out:
# This graph displays the tickets sold relative to the capacity of each venue(data point) and shows how almost every data point will have sold tickets equal or close to capacity
# The two graphs above represent the capacity and attendance per city, respectively; to allow for comparison of whether or not attendance was at, or close to capacity.

# %% [markdown]
# ### Exploring Factors Influencing Venue Capacity: Ticket Prices, Inflation, and Hospitality Gains
#
# We now aim to create multiple scatter plots to explore the relationships between venua capacity and various factors. Each plot includes a regression curve to visualize the trend more clearly. These visualizations aim to uncover potential correlations between these factors and venue capacity.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION
plt.figure(figsize=(6, 2))
plt.scatter(x=reputation_df["Avg. Ticket Price"], y=reputation_df["Attendance"])
sns.regplot(data=reputation_df, x="Avg. Ticket Price", y="Attendance", scatter=False, order=2, color='red')
plt.title("Relationship between Average Ticket Price and Attendance")
plt.xlabel("Avg. Ticket Price")
plt.ylabel("Attendance")
plt.grid(True)  # Add grid lines for better visualization
plt.show()
print("The figure above represents the relationship between average ticket price & attendance, with the red line indicating the trend of the data; This showed how the average ticket price did not seem dependent on the attendance and is most likely dependent on the location")

plt.figure(figsize=(6, 2))
plt.scatter(x=reputation_df["Avg. Inflation CPI (%)"], y=reputation_df["Attendance"])
sns.regplot(data=reputation_df, x="Avg. Inflation CPI (%)", y="Attendance", scatter=False, order=2, color='red')
plt.title("Relationship between Average Inflation CPI and Attendance")
plt.xlabel("Avg. Inflation CPI (%)")
plt.ylabel("Attendance")
plt.grid(True)  # Add grid lines for better visualization
plt.show()
print("The figure above represents the relationship between inflation CPI & attendance, with the red line indicating the trend of the data; Most data points indicated an increase in inflation CPI")

plt.figure(figsize=(6, 2))
plt.scatter(x=reputation_df["Avg. Hosp. Gains (000s)"], y=reputation_df["Attendance"])
sns.regplot(data=reputation_df, x="Avg. Hosp. Gains (000s)", y="Attendance", scatter=False, order=2, color='red')
plt.title("Relationship between Average Hospitability Gains and Attendance")
plt.xlabel("Avg. Hosp. Gains (000s)")
plt.ylabel("Attendance")
plt.grid(True)  # Add grid lines for better visualization
plt.show()
print("The figure above represents the relationship between hospitality cost increases & attendance, with the red line indicating the trend of the data; The majority of data points indicate an increase in hospitability gains.")

plt.figure(figsize=(6, 2))
plt.scatter(x=reputation_df["Food Away Home Inc. (%)"], y=reputation_df["Attendance"])
#sns.regplot(data=reputation_df, x="Food Away Home Inc. (%)", y="Capacity", scatter=False, order=2, color='red')
plt.title("Food Away from Home Cost vs. Attendance")
plt.xlabel("Food Away Home Inc. (%)")
plt.ylabel("Attendance")
plt.grid(True)  # Add grid lines for better visualization
plt.show()
print("The figure above represents the relationship between increase in cost of food & attendance, displaying that most of the data indicates how there is generally an increase in food")
# Out:
# The figure above represents the relationship between average ticket price & attendance, with the red line indicating the trend of the data; This showed how the average ticket price did not seem dependent on the attendance and is most likely dependent on the location
# The figure above represents the relationship between inflation CPI & attendance, with the red line indicating the trend of the data; Most data points indicated an increase in inflation CPI
# The figure above represents the relationship between hospitality cost increases & attendance, with the red line indicating the trend of the data; The majority of data points indicate an increase in hospitability gains.
# The figure above represents the relationship between increase in cost of food & attendance, displaying that most of the data indicates how there is generally an increase in food

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Possible ethical implications include ensuring the informed consent of those whose data may end up being collected, such as their financial or demographic information. However, the datasets we are choosing to utilize contain no personally identifiable information, so there are limited consequences for privacy and confidentiality. There should also be ethical consideration given to the long-term consequences of analyzing and sharing our results to the public, as it may influence others’ public perceptions of Taylor Swift and the Eras Tour, potentially affecting advertising and investment decisions. This may also have ethical implications surrounding the effect on hotels and small businesses/restaurants whose finances we would analyze as part of the local economies of each city, or the disruption to daily lives that local residents face. Thus, we must ensure that the data we collect is accurate and transparent in its collection, so that biases do not lead to inaccurate conclusions that harm the well-being of businesses and communities.

# %% [markdown]
# # Discusison and Conclusion
#
# In 2023, critically acclaimed artist Taylor Swift embarked on “The Eras Tour,” a compilation of over 20 years in the music industry, spanning 11 studio albums and hundreds of songs. A cultural phenomenon, the concert series broke records to be the highest-grossing tour of all time. Following Taylor Swift’s record-breaking Continental United States leg of the Eras Tour, many economists saw significant boosts in the local economies of the cities in her 53 performance stops. States say they saw an increase in millions of spending during the time of Swift’s visits to their locales. Dubbing this phenomenon “Swiftonomics,” cities reported seeing an increase in hospitality demand and the general United States economy noted widespread gains as a result of tourism increases.
#
# Revisiting our initial hypothesis and background, we expected there to be a sharp spike in prices in the hospitality sector due to demand and inflation. Given the principles of supply and demand, we expected that with increasing demand and dwindling supply, the hospitality industry would raise prices in order to increase their profits in a time where they knew there would be a large surge in tourism.
#
# While analyzing the data, we wanted to ensure that particular factors were evaluated, as we know that a combination of a variety of variables can lead to economic changes. Given that different states have different economic conditions and that the value of a dollar can stretch further or shorter depending on the area, it was important for us to consider inflation in regards to the local economy and not the national economy. Concert attendance gave us a rough estimate of how many tourists entered an area. While we know that not all tourists may have participated in hospitality, there is a high chance they partook in either the restaurant or hotel sectors. We then looked at the average hospitality price in terms of room pricing before and after Swift’s visit, increases in jobs in the sector in the month of Swift’s visit, increase in the Consumer Price Index for that month, and any change in the cost of food outside of the home during this time period. With these variables, we can sufficiently complete an analysis on the lodging and restaurant industries in regards to inflation, tourism, and the Eras Tour.
#
# When we look at the relationship between Average Ticket Price and Attendance, we can see that the highest attendance was seen towards the lower end of the price spectrum. However, there is not a telling pattern here as the lowest attendance was seen towards the first and third quarters of the data, which indicates that there may not be a clear pattern. When we look at average attendance in relation to Average Inflation in the Consumer Price Index, we can see that while a few data points indicate declines in inflation, on average, most of the data points sit above the 0% increase line. This implies that most cities saw an increase in inflation during the month of Swift’s visit. On average, jobs in the hospitality sector also followed a similar pattern, with a few data points sitting below 0 implying a decrease in jobs in the sector. However, the majority of the data points still sit above a 0%, indicating that most cities saw an increase in hiring and job positions in the hospitality sector during the month in which Swift was touring. Finally, the cost of food away from home in the given month did not seem to have large gains. Only one data point sits below the 0 line, indicating that only one city saw a decrease in the cost of food outside the household. Most of the other cities’ data points sit between a 0% increase and a 1% increase in prices, with one city being an outlier at a 3% increase in the price of food away from home.
#
# Looking at this data, we can conclude a few things. We can reasonably conclude that Taylor Swift’s Eras Tour had an impact on the hospitality industry. The increase in inflation, jobs in the hospitality industry, and food away from home, specifically in the month of Taylor Swift’s Tour stops demonstrates a correlation between her concert and inflation in the hospitality sector. We believe that increased income in these local cities is largely due to the large influx in tourism as well as the increased prices that were leveraged by the supply and demand of these commodities. This validates our initial hypothesis that there will be increases in inflation in these sectors, however, we do not see as large of a spike in inflation as expected. Most of the increases are not vastly larger than other groups,
#
# In order to demonstrate the absolute validity of these claims, it would be helpful for further research to be conducted on other major events that occur in these cities. Such as if similar gains are seen when a city hosts a SuperBowl or major sporting event, or how Beyonce’s similarly large concert tour impacted the economy of local cities she visited. This will help demonstrate whether or not it is exclusively Swift’s appeal and tour attendance that boosted a local economy, or if concerts and increased tourism in general boost these sectors.
#
#
# # Team Contributions
#
# Sophie Phung:
# I was in charge of most of the writing and analysis of the project, such as the Abstract section, Ethics & Privacy section, and Dataset Description. I also presented in the video and communicated during brainstorming and organization among the group.
#
# Chloe Kwan:
# I was primarily in charge of writing and analysis, including sections such as the Team expectations and Data set description. I also created the slides, recorded, and edited the group video. I also contributed with group brainstorming and early project organization and coordination.
#
# Anik Alam:
# I primarily worked on the data visualizations, so creating and including all of the graphs comparing information in our data set that the group decided to be the most relevant to our question. I also contributed towards finding some of the data that we ended up using.
#
# Anusha Rao:
# I primarily worked on the Research Question, Background, Conclusion and finding the data for our datasets. This involved scraping together data from a multitude of sources that correlated with the Eras Tour. I could not attend the recording of the video due to a final at the same time as most of the group could record, but I contributed to the script. I also contributed towards group brainstorming and project timelines.
#
# Patric Sanchez:
# Identified important variables in the dataset in relation to the context of our project.  Employed data wrangling techniques on the datasets in order to transform and structure the data in a proper manner for future exploratory data analysis use. Performed numerous revisions throughout the duration of our project to ensure the Jupyter Notebook was maintained to a specific standard.
